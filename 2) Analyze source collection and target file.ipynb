# %% [markdown]
# # 2) Analyze source collection and target file
#
# This notebook includes the code to analyze the collection of sounds compiled in the previous notebook and that will be later used as the source collection in our audio mosaicing code. The notebook also contains the code to analyze the target audio file that will be later reconstructed using sound chunks from the source collection.
#
# The audio analysis carried out in this notebook uses the Pythonn bindings of the Essentia library which was introduced in the first session of AMPLAB. Please make sure you checked the [Essentia Python tutorial](https://essentia.upf.edu/documentation/essentia_python_tutorial.html) to get familiarized with using Essentia in Python. Also useful is to always have a browser tab opened with Essentia's [Algorithms Reference](https://essentia.upf.edu/documentation/algorithms_reference.html) documentation page.

# %%
import pandas as pd
import essentia
import essentia.standard as estd
import matplotlib.pyplot as plt
from IPython.display import display, Audio

# %%
# Define here our sound analysis function
# NOTE: remember that if you update this function and want to run a new analysis you'll need to re-run both 
# this cell and the cells below that carry out the audio analysis and that call the analysis function. 
# After analyzing the source collection, make sure the correct descriptors have been 
# extracted by checking the DataFrame contents. DataFrame contents can be printed on screen as a table 
# using 'display(data_frame_object)'

def analyze_sound(audio_path, frame_size=None, audio_id=None):
    """Analyze the audio file given in 'sound_path'.
    Use the parameter 'frame_size' to set the size of the chunks in which the audio will 
    be split for analysis. If no frame_size is given, the whole audio will be analyzed as 
    a single frame.
    Use the 'audio_id' parameter to pass a custom identifier for the audio that will be 
    included in the analysis results. This can be useful to later identify to which file an analysis belongs.
    """
    analysis_output = []  # Here we'll store the analysis results for each chunk (frame) of the audio file
    
    # Load audio file
    loader = estd.MonoLoader(filename=audio_path)
    audio = loader()
    
    # Some processing of frame_size parameter to avoid later problems
    if frame_size is None:
        frame_size = len(audio)  # If no frame_size is given use no frames (analyze all audio at once)
    
    # Calculate the start and end samples for each equally-spaced audio frame
    frame_start_samples = range(0, len(audio)+1, frame_size)
    frame_start_end_samples = zip(frame_start_samples[:-1], frame_start_samples[1:])
    
    # Iterate over audio frames and analyze each one
    for count, (fstart, fend) in enumerate(frame_start_end_samples):
        
        # Get corresponding audio chunk and initialize dictionary to store analysis results with some basic metadata
        frame = audio[fstart:fend]
        frame_output = {
            'freesound_id': audio_id,
            'id': '{0}_f{1}'.format(audio_id, count),
            'path': audio_path,
            'start_sample': fstart,
            'end_sample': fend,
        }
        
        # Extract loudness
        loudness_algo = estd.Loudness()
        loudness = loudness_algo(frame)
        frame_output['loudness'] = loudness / len(frame)  # Normalize by length of frame

        # Extract MFCC coefficients
        w_algo = estd.Windowing(type = 'hann')
        spectrum_algo = estd.Spectrum()
        mfcc_algo = estd.MFCC()
        spec = spectrum_algo(w_algo(frame))
        _, mfcc_coeffs = mfcc_algo(spec)
        frame_output.update({'mfcc_{0}'.format(j): mfcc_coeffs[j] for j in range(0, len(mfcc_coeffs))})
        
        # Extract other features here and add to 'frame_output' dictionary
        flux_algo = estd.Flux()
        flux = flux_algo(frame)
        frame_output['flux'] = flux / len(frame)  # Normalize by length of frame
        
        spectral_centroid_time_algo = estd.SpectralCentroidTime()
        spectral_centroid_time = spectral_centroid_time_algo(frame)
        frame_output['spectral_centroid_time'] = spectral_centroid_time
        
        rolloff_algo = estd.RollOff()
        rolloff = rolloff_algo(frame)
        frame_output['rolloff'] = rolloff
        
        # Add frame analysis results to output
        analysis_output.append(frame_output)
        #print(analysis_output)

    return analysis_output

# %% [markdown]
# ## Analyze source collection

# %%
DATAFRAME_FILENAME = 'dataframe.csv'  # DataFrame file of the sound source collection to analyze
DATAFRAME_SOURCE_FILENAME = 'dataframe_source.csv'  # DataFrame file where to store the results of our analysis

# Load the DataFrame of the sound source collection created in previous notebook and analyze all sound files in it
df = pd.read_csv(open(DATAFRAME_FILENAME), index_col=0)
analyses = []
for i in range(0, len(df)):
    sound = df.iloc[i]  # Get DataFrame sound at position 'i'
    print('Analyzing sound with id {0} [{1}/{2}]'.format(sound['freesound_id'], i + 1, len(df)))
    analysis_output = analyze_sound(sound['path'], frame_size=None, audio_id=sound['freesound_id'])  # Split audio in chunks of 200ms (44100/5 samples)
    analyses += analysis_output

# Store analysis results in a new Pandas DataFrame and save it
df_source = pd.DataFrame(analyses)
df_source.to_csv(DATAFRAME_SOURCE_FILENAME)
print('Saved source DataFrame with {0} entries! {1}'.format(len(df_source), DATAFRAME_SOURCE_FILENAME))

display(df_source)  # Show DataFrane contents
df_source.describe()  # Show some statistics of numerical fields in the DataFrame
# Out:
# Analyzing sound with id 205972 [1/150]
# Analyzing sound with id 205974 [2/150]
# Analyzing sound with id 205975 [3/150]
# Analyzing sound with id 206022 [4/150]
# Analyzing sound with id 222134 [5/150]
# Analyzing sound with id 222147 [6/150]
# Analyzing sound with id 222149 [7/150]
# Analyzing sound with id 222152 [8/150]
# Analyzing sound with id 222153 [9/150]
# Analyzing sound with id 222158 [10/150]
# Analyzing sound with id 222159 [11/150]
# Analyzing sound with id 222162 [12/150]
# Analyzing sound with id 222163 [13/150]
# Analyzing sound with id 222165 [14/150]
# Analyzing sound with id 222166 [15/150]
# Analyzing sound with id 222167 [16/150]
# Analyzing sound with id 222168 [17/150]
# Analyzing sound with id 222169 [18/150]
# Analyzing sound with id 222171 [19/150]
# Analyzing sound with id 222173 [20/150]
# Analyzing sound with id 222174 [21/150]
# Analyzing sound with id 222175 [22/150]
# Analyzing sound with id 222177 [23/150]
# Analyzing sound with id 222178 [24/150]
# Analyzing sound with id 222179 [25/150]
# Analyzing sound with id 222180 [26/150]
# Analyzing sound with id 222181 [27/150]
# Analyzing sound with id 222182 [28/150]
# Analyzing sound with id 222183 [29/150]
# Analyzing sound with id 222191 [30/150]
# Analyzing sound with id 222206 [31/150]
# Analyzing sound with id 222212 [32/150]
# Analyzing sound with id 222214 [33/150]
# Analyzing sound with id 222215 [34/150]
# Analyzing sound with id 222227 [35/150]
# Analyzing sound with id 222234 [36/150]
# Analyzing sound with id 222235 [37/150]
# Analyzing sound with id 222236 [38/150]
# Analyzing sound with id 222238 [39/150]
# Analyzing sound with id 222240 [40/150]
# Analyzing sound with id 222241 [41/150]
# Analyzing sound with id 222242 [42/150]
# Analyzing sound with id 222245 [43/150]
# Analyzing sound with id 222250 [44/150]
# Analyzing sound with id 222252 [45/150]
# Analyzing sound with id 222253 [46/150]
# Analyzing sound with id 222254 [47/150]
# Analyzing sound with id 222255 [48/150]
# Analyzing sound with id 222256 [49/150]
# Analyzing sound with id 222258 [50/150]
# Analyzing sound with id 222259 [51/150]
# Analyzing sound with id 222261 [52/150]
# Analyzing sound with id 222262 [53/150]
# Analyzing sound with id 222263 [54/150]
# Analyzing sound with id 222264 [55/150]
# Analyzing sound with id 222265 [56/150]
# Analyzing sound with id 222266 [57/150]
# Analyzing sound with id 222267 [58/150]
# Analyzing sound with id 222268 [59/150]
# Analyzing sound with id 222269 [60/150]
# Analyzing sound with id 222270 [61/150]
# Analyzing sound with id 222272 [62/150]
# Analyzing sound with id 222273 [63/150]
# Analyzing sound with id 222276 [64/150]
# Analyzing sound with id 222278 [65/150]
# Analyzing sound with id 222279 [66/150]
# Analyzing sound with id 222282 [67/150]
# Analyzing sound with id 222284 [68/150]
# Analyzing sound with id 222285 [69/150]
# Analyzing sound with id 222286 [70/150]
# Analyzing sound with id 222288 [71/150]
# Analyzing sound with id 222289 [72/150]
# Analyzing sound with id 222290 [73/150]
# Analyzing sound with id 222291 [74/150]
# Analyzing sound with id 222293 [75/150]
# Analyzing sound with id 222294 [76/150]
# Analyzing sound with id 222295 [77/150]
# Analyzing sound with id 222297 [78/150]
# Analyzing sound with id 222298 [79/150]
# Analyzing sound with id 222299 [80/150]
# Analyzing sound with id 222300 [81/150]
# Analyzing sound with id 222301 [82/150]
# Analyzing sound with id 222302 [83/150]
# Analyzing sound with id 222303 [84/150]
# Analyzing sound with id 222305 [85/150]
# Analyzing sound with id 222306 [86/150]
# Analyzing sound with id 222307 [87/150]
# Analyzing sound with id 222308 [88/150]
# Analyzing sound with id 222310 [89/150]
# Analyzing sound with id 222311 [90/150]
# Analyzing sound with id 222312 [91/150]
# Analyzing sound with id 222315 [92/150]
# Analyzing sound with id 222316 [93/150]
# Analyzing sound with id 222318 [94/150]
# Analyzing sound with id 222319 [95/150]
# Analyzing sound with id 222322 [96/150]
# Analyzing sound with id 222324 [97/150]
# Analyzing sound with id 222325 [98/150]
# Analyzing sound with id 222326 [99/150]
# Analyzing sound with id 222333 [100/150]
# Analyzing sound with id 222335 [101/150]
# Analyzing sound with id 222336 [102/150]
# Analyzing sound with id 222338 [103/150]
# Analyzing sound with id 222339 [104/150]
# Analyzing sound with id 222340 [105/150]
# Analyzing sound with id 222341 [106/150]
# Analyzing sound with id 222342 [107/150]
# Analyzing sound with id 222343 [108/150]
# Analyzing sound with id 222345 [109/150]
# Analyzing sound with id 222346 [110/150]
# Analyzing sound with id 222347 [111/150]
# Analyzing sound with id 222348 [112/150]
# Analyzing sound with id 222350 [113/150]
# Analyzing sound with id 222351 [114/150]
# Analyzing sound with id 222352 [115/150]
# Analyzing sound with id 222353 [116/150]
# Analyzing sound with id 222354 [117/150]
# Analyzing sound with id 222355 [118/150]
# Analyzing sound with id 222356 [119/150]
# Analyzing sound with id 222357 [120/150]
# Analyzing sound with id 222358 [121/150]
# Analyzing sound with id 222359 [122/150]
# Analyzing sound with id 222360 [123/150]
# Analyzing sound with id 222361 [124/150]
# Analyzing sound with id 222146 [125/150]
# Analyzing sound with id 222170 [126/150]
# Analyzing sound with id 205973 [127/150]
# Analyzing sound with id 206023 [128/150]
# Analyzing sound with id 222233 [129/150]
# Analyzing sound with id 222132 [130/150]
# Analyzing sound with id 222133 [131/150]
# Analyzing sound with id 222135 [132/150]
# Analyzing sound with id 222136 [133/150]
# Analyzing sound with id 222137 [134/150]
# Analyzing sound with id 222138 [135/150]
# Analyzing sound with id 222139 [136/150]
# Analyzing sound with id 222140 [137/150]
# Analyzing sound with id 222141 [138/150]
# Analyzing sound with id 222142 [139/150]
# Analyzing sound with id 222143 [140/150]
# Analyzing sound with id 222144 [141/150]
# Analyzing sound with id 222145 [142/150]
# Analyzing sound with id 222148 [143/150]
# Analyzing sound with id 222150 [144/150]
# Analyzing sound with id 222151 [145/150]
# Analyzing sound with id 222154 [146/150]
# Analyzing sound with id 222155 [147/150]
# Analyzing sound with id 222156 [148/150]
# Analyzing sound with id 222157 [149/150]
# Analyzing sound with id 222160 [150/150]
# Saved source DataFrame with 150 entries! dataframe_source.csv
#      end_sample      flux  freesound_id         id  loudness       mfcc_0  \
# 0        132672  0.000089        205972  205972_f0  0.000205 -1103.347534
# 1         46400  0.000339        205974  205974_f0  0.000864  -918.377380
# 2        149504  0.000171        205975  205975_f0  0.000513  -970.445129
# 3         61376  0.000260        206022  206022_f0  0.000667  -993.611755
# 4         25920  0.000188        222134  222134_f0  0.000321 -1081.592651
# 5          8896  0.000323        222147  222147_f0  0.000463  -962.073730
# 6          4032  0.000414        222149  222149_f0  0.000493  -893.791687
# 7          8704  0.001796        222152  222152_f0  0.004575  -757.503174
# 8         10560  0.000546        222153  222153_f0  0.000990  -921.223755
# 9         11456  0.001405        222158  222158_f0  0.003613  -853.008423
# 10        10304  0.001332        222159  222159_f0  0.003245  -804.120544
# 11        10176  0.001065        222162  222162_f0  0.002396  -831.899658
# 12         9728  0.001710        222163  222163_f0  0.004447  -770.496887
# 13        10176  0.001153        222165  222165_f0  0.002664  -812.521118
# 14        10432  0.001202        222166  222166_f0  0.002841  -839.868591
# 15         9280  0.001296        222167  222167_f0  0.003018  -798.061890
# 16         9408  0.001288        222168  222168_f0  0.003007  -787.155090
# 17        10688  0.001086        222169  222169_f0  0.002501  -848.697388
# 18        10048  0.001219        222171  222171_f0  0.002857  -820.270630
# 19         8896  0.001369        222173  222173_f0  0.003203  -818.023254
# 20         9536  0.000641        222174  222174_f0  0.001186  -883.769043
# 21        10304  0.001209        222175  222175_f0  0.002850  -816.974487
# 22        12608  0.001059        222177  222177_f0  0.002556  -849.484497
# 23        13504  0.000938        222178  222178_f0  0.002223  -909.012878
# 24        10816  0.001567        222179  222179_f0  0.004101  -809.589355
# 25        10560  0.001081        222180  222180_f0  0.002473  -781.466553
\
# count  150.000000  150.000000  150.000000  150.000000  150.000000  150.000000
# mean   -24.691968   16.024898    2.328279   -2.124506  -70.407268   10.870003
# std     49.645339   14.381742   14.445573   10.853694   36.386812   14.944159
# min   -115.933617  -16.580603  -30.334301  -36.905621 -123.611061  -22.058392
# 25%    -71.041550    5.282921  -10.295857  -10.477081  -97.936970    0.746608
# 50%    -22.877869   13.979610   -0.087660   -0.603449  -75.585297    8.046810
# 75%     11.523012   28.038008   15.086854    5.840147  -48.651029   18.526466
# max    115.240288   48.530933   36.098785   23.308580   29.527927   48.649670
#
#            mfcc_4      mfcc_5      mfcc_6      mfcc_7      mfcc_8      mfcc_9  \
# count  150.000000  150.000000  150.000000  150.000000  150.000000  150.000000
# mean     4.402346   11.425811    1.544595    8.881444    3.750792   14.476996
# std     17.189788   15.985165   13.455457   11.574651   12.131265   13.633533
# min    -38.148464  -21.740448  -28.212658  -23.975060  -28.224810  -16.206116
# 25%     -7.112190    0.674931   -9.247074    0.710150   -2.634316    2.197285
# 50%      3.046872    8.614571    2.174408   10.171193    6.363319   14.899071
# 75%     13.921678   22.851214   12.382465   16.926380   13.110856   24.744745
# max     45.537052   52.036137   36.841534   35.628899   25.062958   45.589890
#
#             rolloff  spectral_centroid_time  start_sample
# count    150.000000              150.000000         150.0
# mean    5550.827629             3393.660772           0.0
# std     2926.052380             1214.649081           0.0
# min     1011.399658              362.082764           0.0
# 25%     3767.557068             2752.898682           0.0
# 50%     4889.052246             3262.404053           0.0
# 75%     6378.832397             3865.416199           0.0
# max    18463.630859             7451.187988           0.0

# %% [markdown]
# ## Analyze the target sound file

# %%
def analyze_target_sound(audio_path, frame_size=None, hop_size=None, audio_id=None):
    analysis_output = []  # Here we'll store the analysis results for each chunk (frame) of the audio file
    
    # Load audio file
    loader = estd.MonoLoader(filename=audio_path)
    audio = loader()
    
    # Onset detection
    # Phase 1: compute the onset detection function
    od = estd.OnsetDetection(method='hfc')
    
    # Let's also get the other algorithms we will need, and a pool to store the results
    w = estd.Windowing(type = 'hann')
    fft = estd.FFT() # this gives us a complex FFT
    c2p = estd.CartesianToPolar() # and this turns it into a pair (magnitude, phase)
    pool = estd.essentia.Pool()
    
    # Computing onset detection functions.
    for frame in estd.FrameGenerator(audio, frameSize = frame_size, hopSize = hop_size):
        mag, phase, = c2p(fft(w(frame)))
        pool.add('features.hfc', od(mag, phase))
    
    # Phase 2: compute the actual onsets samples
    onsets = estd.Onsets()
    
    onsets_hfc = onsets(# this algo expects a matrix, not a vector
                    essentia.array([ pool['features.hfc'] ]),

                    # you need to specify weights, but as there is only a single
                    # function, it doesn't actually matter which weight you give it
                    [ 1 ])
    
    onsets_hfc_samples = [int(round(i*44100)) for i in onsets_hfc]
    
    # Calculate the start and end samples for each audio frame
    frame_start_end_samples = zip(onsets_hfc_samples[:-1], onsets_hfc_samples[1:])
    
    # Iterate over audio frames and analyze each one
    for count, (fstart, fend) in enumerate(frame_start_end_samples):
        
        # Get corresponding audio chunk and initialize dictionary to store analysis results with some basic metadata
        frame = audio[fstart:fend]
        frame_output = {
            'freesound_id': audio_id,
            'id': '{0}_f{1}'.format(audio_id, count),
            'path': audio_path,
            'start_sample': fstart,
            'end_sample': fend,
        }
        
        # Extract loudness
        loudness_algo = estd.Loudness()
        loudness = loudness_algo(frame)
        frame_output['loudness'] = loudness / len(frame)  # Normalize by length of frame

        # Extract MFCC coefficients
        w_algo = estd.Windowing(type = 'hann')
        spectrum_algo = estd.Spectrum()
        mfcc_algo = estd.MFCC()
        spec = spectrum_algo(w_algo(frame))
        _, mfcc_coeffs = mfcc_algo(spec)
        frame_output.update({'mfcc_{0}'.format(j): mfcc_coeffs[j] for j in range(0, len(mfcc_coeffs))})
        
        # Extract other features here and add to 'frame_output' dictionary
        flux_algo = estd.Flux()
        flux = flux_algo(frame)
        frame_output['flux'] = flux / len(frame)  # Normalize by length of frame
        
        spectral_centroid_time_algo = estd.SpectralCentroidTime()
        spectral_centroid_time = spectral_centroid_time_algo(frame)
        frame_output['spectral_centroid_time'] = spectral_centroid_time
        
        rolloff_algo = estd.RollOff()
        rolloff = rolloff_algo(frame)
        frame_output['rolloff'] = rolloff
        
        # Add frame analysis results to output
        analysis_output.append(frame_output)
        #print(analysis_output)

    return analysis_output

# %%
TARGET_SOUND_PATH = '464784__thenotoriousszin__linn-loop.wav'  # Filename of the target audio we'll reconstruct
DATAFRAME_TARGET_FILE_FILENAME = 'dataframe_target.csv'  # DataFrame file where to store the analysis results of the target audio

# Analyze the target audio file and store results in a new DataFrame
print('Analyzing target sound {0}'.format(TARGET_SOUND_PATH))
target_analysis = analyze_target_sound(TARGET_SOUND_PATH, frame_size=1024, hop_size=512)  # Also split audio in chunks of 200ms (44100/5 samples) 
df_target = pd.DataFrame(target_analysis)
df_target.to_csv(DATAFRAME_TARGET_FILE_FILENAME)
print('Saved target dataframe with {0} entries! {1}'.format(len(df_target), DATAFRAME_TARGET_FILE_FILENAME))

# Plot target audio file waveform and show ticks at the start samples of the chunks
plt.figure(figsize=(15,2.5))
audio = estd.MonoLoader(filename=TARGET_SOUND_PATH)()
plt.plot(audio)
plt.vlines(df_target['start_sample'].values, -1, 1, color='red')
plt.axis([0, min(len(audio), 44100 * 4), -1, 1])
#plt.title('Target audio file (first 4 seconds)')
plt.show()

display(df_target)  # Show data frame contents
df_target.describe()  # Show statistics of numerical fields in data frame
# Out:
# Analyzing target sound 464784__thenotoriousszin__linn-loop.wav
# Saved target dataframe with 170 entries! dataframe_target.csv
#      end_sample      flux freesound_id         id  loudness      mfcc_0  \
# 0          6144  0.004598         None    None_f0  0.013902 -666.187805
# 1         24064  0.001867         None    None_f1  0.006159 -879.739258
# 2         30208  0.004610         None    None_f2  0.014369 -610.472900
# 3         48128  0.001880         None    None_f3  0.006214 -880.121460
# 4         72192  0.001338         None    None_f4  0.004358 -940.532410
# 5         90624  0.001655         None    None_f5  0.005290 -889.451477
# 6         96256  0.002916         None    None_f6  0.007551 -670.084839
# 7        120320  0.001296         None    None_f7  0.004176 -942.214905
# 8        144384  0.000907         None    None_f8  0.002587 -925.181641
# 9        150528  0.004475         None    None_f9  0.013807 -617.485168
# 10       168448  0.001867         None   None_f10  0.006157 -882.440613
# 11       174592  0.004611         None   None_f11  0.014372 -618.595703
# 12       192512  0.001879         None   None_f12  0.006213 -882.950806
# 13       216576  0.001339         None   None_f13  0.004360 -942.829224
# 14       235008  0.001656         None   None_f14  0.005293 -892.931030
