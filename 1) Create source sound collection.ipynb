# %% [markdown]
# # 1) Create source sound collection
#
# This notebook includes the code to create the collection of sounds that will later be used as source material for our audio mosaicing application. The collection of sounds is created by defining a number of queries to be performed using the Freesound API and concatenanting the results of each query. A number of metadata fields are stored for each sound in the collection and saved into a Pandas DataFrame object and CSV file in disk. For each sound in the collection, we also download an OGG preview and store it in disk.
#
# This notebook uses the `freesound` Python package for interacting with the Freesound API. The source code for this package can be found here: https://github.com/mtg/freesound-python. In this repository you'll find a Python script with [examples](https://github.com/MTG/freesound-python/blob/master/examples.py) to learn how to interact with the API. Nevertheless, if you are further interested in the Freesound API, check the [API documentation](http://freesound.org/docs/api/) which provides more information.
#
# **NOTE**: A Freesound API key is provided in this notebook, but you should make a Freesound account and get your own key. You can get a key here: https://freesound.org/apiv2/apply/

# %%
import os
import pandas as pd
import numpy as np
import freesound
from IPython.display import display

FREESOUND_API_KEY = 'mIM0Yo9x2jkzgfOVUG1R1VGYV6em4kBHSQy97qr7'  # Please replace by your own Freesound API key
FILES_DIR = 'files'  # Place where to store the downloaded diles. Will be relative to the current folder.
DATAFRAME_FILENAME = 'dataframe.csv'  # File where we'll store the metadata of our sounds collection
FREESOUND_STORE_METADATA_FIELDS = ['id', 'name', 'username', 'previews', 'license', 'tags']  # Freesound metadata properties to store

freesound_client = freesound.FreesoundClient()
freesound_client.set_token(FREESOUND_API_KEY)
if not os.path.exists(FILES_DIR): os.mkdir(FILES_DIR)

# %%
# Define some util functions

def query_freesound(query, filter, num_results=10):
    """Queries freesound with the given query and filter values.
    If no filter is given, a default filter is added to only get sounds shorter than 30 seconds.
    """
    if filter is None:
        filter = 'duration:[0 TO 30]'  # Set default filter
    pager = freesound_client.text_search(
        query = query,
        filter = filter,
        fields = ','.join(FREESOUND_STORE_METADATA_FIELDS),
        group_by_pack = 0,
        page_size = num_results
    )
    return [sound for sound in pager]

def retrieve_sound_preview(sound, directory):
    """Download the high-quality OGG sound preview of a given Freesound sound object to the given directory.
    """
    return freesound.FSRequest.retrieve(
        sound.previews.preview_hq_ogg,
        freesound_client,
        os.path.join(directory, sound.previews.preview_hq_ogg.split('/')[-1])
    )

def make_pandas_record(sound):
    """Create a dictionary with the metadata that we want to store for each sound.
    """
    record = {key: sound.as_dict()[key] for key in FREESOUND_STORE_METADATA_FIELDS}
    del record['previews']  # Don't store previews dict in record
    record['freesound_id'] = record['id']  # Rename 'id' to 'freesound_id'
    del record['id']
    record['path'] = "files/" + sound.previews.preview_hq_ogg.split("/")[-1]  # Store path of downloaded file
    return record

# %%
# Build our collection of sounds

# Our collection of sounds is made by appending the results of a number of different queries to freesound
# The query terms, query filters and the number of results per query are all defined here.
# Information about how to define filters can be found in the Freesound API documentation: https://freesound.org/docs/api/resources_apiv2.html#request-parameters-text-search-parameters
freesound_queries = [
    {
        'query': 'beijin-opera dataset',
        'filter': None,
        'num_results': 200, 
    },
]

# Do all queries and concatenate the results in a single list of sounds
sounds = sum([query_freesound(query['query'], query['filter'], query['num_results']) for query in freesound_queries],[])

# Download the sounds and save them to FILES_DIR folder
for count, sound in enumerate(sounds):
    print('Downloading sound with id {0} [{1}/{2}]'.format(sound.id, count + 1, len(sounds)))
    retrieve_sound_preview(sound, 'files/')
    
# Make a Pandas DataFrame with the metadata of our sound collection and save it
df =  pd.DataFrame([make_pandas_record(s) for s in sounds])
df.to_csv(DATAFRAME_FILENAME)
print('Saved DataFrame with {0} entries! {1}'.format(len(df), DATAFRAME_FILENAME))

# Show the contents of our DataFrame (the metadata of our source collection)
display(df)
# Out:
# Downloading sound with id 205972 [1/150]
# Downloading sound with id 205974 [2/150]
# Downloading sound with id 205975 [3/150]
# Downloading sound with id 206022 [4/150]
# Downloading sound with id 222134 [5/150]
# Downloading sound with id 222147 [6/150]
# Downloading sound with id 222149 [7/150]
# Downloading sound with id 222152 [8/150]
# Downloading sound with id 222153 [9/150]
# Downloading sound with id 222158 [10/150]
# Downloading sound with id 222159 [11/150]
# Downloading sound with id 222162 [12/150]
# Downloading sound with id 222163 [13/150]
# Downloading sound with id 222165 [14/150]
# Downloading sound with id 222166 [15/150]
# Downloading sound with id 222167 [16/150]
# Downloading sound with id 222168 [17/150]
# Downloading sound with id 222169 [18/150]
# Downloading sound with id 222171 [19/150]
# Downloading sound with id 222173 [20/150]
# Downloading sound with id 222174 [21/150]
# Downloading sound with id 222175 [22/150]
# Downloading sound with id 222177 [23/150]
# Downloading sound with id 222178 [24/150]
# Downloading sound with id 222179 [25/150]
# Downloading sound with id 222180 [26/150]
# Downloading sound with id 222181 [27/150]
# Downloading sound with id 222182 [28/150]
# Downloading sound with id 222183 [29/150]
# Downloading sound with id 222191 [30/150]
# Downloading sound with id 222206 [31/150]
# Downloading sound with id 222212 [32/150]
# Downloading sound with id 222214 [33/150]
# Downloading sound with id 222215 [34/150]
# Downloading sound with id 222227 [35/150]
# Downloading sound with id 222234 [36/150]
# Downloading sound with id 222235 [37/150]
# Downloading sound with id 222236 [38/150]
# Downloading sound with id 222238 [39/150]
# Downloading sound with id 222240 [40/150]
# Downloading sound with id 222241 [41/150]
# Downloading sound with id 222242 [42/150]
# Downloading sound with id 222245 [43/150]
# Downloading sound with id 222250 [44/150]
# Downloading sound with id 222252 [45/150]
# Downloading sound with id 222253 [46/150]
# Downloading sound with id 222254 [47/150]
# Downloading sound with id 222255 [48/150]
# Downloading sound with id 222256 [49/150]
# Downloading sound with id 222258 [50/150]
# Downloading sound with id 222259 [51/150]
# Downloading sound with id 222261 [52/150]
# Downloading sound with id 222262 [53/150]
# Downloading sound with id 222263 [54/150]
# Downloading sound with id 222264 [55/150]
# Downloading sound with id 222265 [56/150]
# Downloading sound with id 222266 [57/150]
# Downloading sound with id 222267 [58/150]
# Downloading sound with id 222268 [59/150]
# Downloading sound with id 222269 [60/150]
# Downloading sound with id 222270 [61/150]
# Downloading sound with id 222272 [62/150]
# Downloading sound with id 222273 [63/150]
# Downloading sound with id 222276 [64/150]
# Downloading sound with id 222278 [65/150]
# Downloading sound with id 222279 [66/150]
# Downloading sound with id 222282 [67/150]
# Downloading sound with id 222284 [68/150]
# Downloading sound with id 222285 [69/150]
# Downloading sound with id 222286 [70/150]
# Downloading sound with id 222288 [71/150]
# Downloading sound with id 222289 [72/150]
# Downloading sound with id 222290 [73/150]
# Downloading sound with id 222291 [74/150]
# Downloading sound with id 222293 [75/150]
# Downloading sound with id 222294 [76/150]
# Downloading sound with id 222295 [77/150]
# Downloading sound with id 222297 [78/150]
# Downloading sound with id 222298 [79/150]
# Downloading sound with id 222299 [80/150]
# Downloading sound with id 222300 [81/150]
# Downloading sound with id 222301 [82/150]
# Downloading sound with id 222302 [83/150]
# Downloading sound with id 222303 [84/150]
# Downloading sound with id 222305 [85/150]
# Downloading sound with id 222306 [86/150]
# Downloading sound with id 222307 [87/150]
# Downloading sound with id 222308 [88/150]
# Downloading sound with id 222310 [89/150]
# Downloading sound with id 222311 [90/150]
# Downloading sound with id 222312 [91/150]
# Downloading sound with id 222315 [92/150]
# Downloading sound with id 222316 [93/150]
# Downloading sound with id 222318 [94/150]
# Downloading sound with id 222319 [95/150]
# Downloading sound with id 222322 [96/150]
# Downloading sound with id 222324 [97/150]
# Downloading sound with id 222325 [98/150]
# Downloading sound with id 222326 [99/150]
# Downloading sound with id 222333 [100/150]
# Downloading sound with id 222335 [101/150]
# Downloading sound with id 222336 [102/150]
# Downloading sound with id 222338 [103/150]
# Downloading sound with id 222339 [104/150]
# Downloading sound with id 222340 [105/150]
# Downloading sound with id 222341 [106/150]
# Downloading sound with id 222342 [107/150]
# Downloading sound with id 222343 [108/150]
# Downloading sound with id 222345 [109/150]
# Downloading sound with id 222346 [110/150]
# Downloading sound with id 222347 [111/150]
# Downloading sound with id 222348 [112/150]
# Downloading sound with id 222350 [113/150]
# Downloading sound with id 222351 [114/150]
# Downloading sound with id 222352 [115/150]
# Downloading sound with id 222353 [116/150]
# Downloading sound with id 222354 [117/150]
# Downloading sound with id 222355 [118/150]
# Downloading sound with id 222356 [119/150]
# Downloading sound with id 222357 [120/150]
# Downloading sound with id 222358 [121/150]
# Downloading sound with id 222359 [122/150]
# Downloading sound with id 222360 [123/150]
# Downloading sound with id 222361 [124/150]
# Downloading sound with id 222146 [125/150]
# Downloading sound with id 222170 [126/150]
# Downloading sound with id 205973 [127/150]
# Downloading sound with id 206023 [128/150]
# Downloading sound with id 222233 [129/150]
# Downloading sound with id 222132 [130/150]
# Downloading sound with id 222133 [131/150]
# Downloading sound with id 222135 [132/150]
# Downloading sound with id 222136 [133/150]
# Downloading sound with id 222137 [134/150]
# Downloading sound with id 222138 [135/150]
# Downloading sound with id 222139 [136/150]
# Downloading sound with id 222140 [137/150]
# Downloading sound with id 222141 [138/150]
# Downloading sound with id 222142 [139/150]
# Downloading sound with id 222143 [140/150]
# Downloading sound with id 222144 [141/150]
# Downloading sound with id 222145 [142/150]
# Downloading sound with id 222148 [143/150]
# Downloading sound with id 222150 [144/150]
# Downloading sound with id 222151 [145/150]
# Downloading sound with id 222154 [146/150]
# Downloading sound with id 222155 [147/150]
# Downloading sound with id 222156 [148/150]
# Downloading sound with id 222157 [149/150]
# Downloading sound with id 222160 [150/150]
# Saved DataFrame with 150 entries! dataframe.csv
#      freesound_id                                      license        name  \
# 0          205972  http://creativecommons.org/licenses/by/3.0/    daluo_01
# 1          205974  http://creativecommons.org/licenses/by/3.0/  xiaoluo_01
# 2          205975  http://creativecommons.org/licenses/by/3.0/    naobo_05
# 3          206022  http://creativecommons.org/licenses/by/3.0/  xiaoluo_34
# 4          222134  http://creativecommons.org/licenses/by/3.0/    bangu_03
# 5          222147  http://creativecommons.org/licenses/by/3.0/    bangu_17
# 6          222149  http://creativecommons.org/licenses/by/3.0/    bangu_19
# 7          222152  http://creativecommons.org/licenses/by/3.0/    bangu_22
# 8          222153  http://creativecommons.org/licenses/by/3.0/    bangu_23
# 9          222158  http://creativecommons.org/licenses/by/3.0/    bangu_28
# 10         222159  http://creativecommons.org/licenses/by/3.0/    bangu_29
# 11         222162  http://creativecommons.org/licenses/by/3.0/    bangu_32
# 12         222163  http://creativecommons.org/licenses/by/3.0/    bangu_33
# 13         222165  http://creativecommons.org/licenses/by/3.0/    bangu_35
# 14         222166  http://creativecommons.org/licenses/by/3.0/    bangu_36
# 15         222167  http://creativecommons.org/licenses/by/3.0/    bangu_37
# 16         222168  http://creativecommons.org/licenses/by/3.0/    bangu_38
# 17         222169  http://creativecommons.org/licenses/by/3.0/    bangu_39
# 18         222171  http://creativecommons.org/licenses/by/3.0/    bangu_41
# 19         222173  http://creativecommons.org/licenses/by/3.0/    bangu_43
# 20         222174  http://creativecommons.org/licenses/by/3.0/    bangu_44
# 21         222175  http://creativecommons.org/licenses/by/3.0/    bangu_45
# 22         222177  http://creativecommons.org/licenses/by/3.0/    bangu_47
# 23         222178  http://creativecommons.org/licenses/by/3.0/    bangu_48
# 24         222179  http://creativecommons.org/licenses/by/3.0/    bangu_49
# 25         222180  http://creativecommons.org/licenses/by/3.0/    bangu_50
# 26         222181  http://creativecommons.org/licenses/by/3.0/    bangu_51
# 27         222182  http://creativecommons.org/licenses/by/3.0/    bangu_52
# 28         222183  http://creativecommons.org/licenses/by/3.0/    bangu_53
# 29         222191  http://creativecommons.org/licenses/by/3.0/    daluo_03
# ..            ...                                          ...         ...
# 120        222358  http://creativecommons.org/licenses/by/3.0/  xiaoluo_62
# 121        222359  http://creativecommons.org/licenses/by/3.0/  xiaoluo_63
# 122        222360  http://creativecommons.org/licenses/by/3.0/  xiaoluo_64
# 123        222361  http://creativecommons.org/licenses/by/3.0/  xiaoluo_65
# 124        222146  http://creativecommons.org/licenses/by/3.0/    bangu_16
# 125        222170  http://creativecommons.org/licenses/by/3.0/    bangu_40
# 126        205973  http://creativecommons.org/licenses/by/3.0/    bangu_06
# 127        206023  http://creativecommons.org/licenses/by/3.0/    daluo_04
# 128        222233  http://creativecommons.org/licenses/by/3.0/    daluo_46
# 129        222132  http://creativecommons.org/licenses/by/3.0/    bangu_01
# 130        222133  http://creativecommons.org/licenses/by/3.0/    bangu_02
# 131        222135  http://creativecommons.org/licenses/by/3.0/    bangu_04
# 132        222136  http://creativecommons.org/licenses/by/3.0/    bangu_05
# 133        222137  http://creativecommons.org/licenses/by/3.0/    bangu_07
# 134        222138  http://creativecommons.org/licenses/by/3.0/    bangu_08
# 135        222139  http://creativecommons.org/licenses/by/3.0/    bangu_09
# 136        222140  http://creativecommons.org/licenses/by/3.0/    bangu_10
# 137        222141  http://creativecommons.org/licenses/by/3.0/    bangu_11
# 138        222142  http://creativecommons.org/licenses/by/3.0/    bangu_12
# 139        222143  http://creativecommons.org/licenses/by/3.0/    bangu_13
# 140        222144  http://creativecommons.org/licenses/by/3.0/    bangu_14
# 141        222145  http://creativecommons.org/licenses/by/3.0/    bangu_15
# 142        222148  http://creativecommons.org/licenses/by/3.0/    bangu_18
# 143        222150  http://creativecommons.org/licenses/by/3.0/    bangu_20
# 144        222151  http://creativecommons.org/licenses/by/3.0/    bangu_21
# 145        222154  http://creativecommons.org/licenses/by/3.0/    bangu_24
# 146        222155  http://creativecommons.org/licenses/by/3.0/    bangu_25
# 147        222156  http://creativecommons.org/licenses/by/3.0/    bangu_26
# 148        222157  http://creativecommons.org/licenses/by/3.0/    bangu_27
# 149        222160  http://creativecommons.org/licenses/by/3.0/    bangu_30
#
#                             path  \
# 0    files/205972_2385996-hq.ogg
# 1    files/205974_2385996-hq.ogg
# 2    files/205975_2385996-hq.ogg
# 3    files/206022_2385996-hq.ogg
# 4    files/222134_2385996-hq.ogg
# 5    files/222147_2385996-hq.ogg
# 6    files/222149_2385996-hq.ogg
# 7    files/222152_2385996-hq.ogg
# 8    files/222153_2385996-hq.ogg
# 9    files/222158_2385996-hq.ogg
# 10   files/222159_2385996-hq.ogg
# 11   files/222162_2385996-hq.ogg
# 12   files/222163_2385996-hq.ogg
# 13   files/222165_2385996-hq.ogg
# 14   files/222166_2385996-hq.ogg
# 15   files/222167_2385996-hq.ogg
# 16   files/222168_2385996-hq.ogg
# 17   files/222169_2385996-hq.ogg
# 18   files/222171_2385996-hq.ogg
# 19   files/222173_2385996-hq.ogg
# 20   files/222174_2385996-hq.ogg
# 21   files/222175_2385996-hq.ogg
# 22   files/222177_2385996-hq.ogg
# 23   files/222178_2385996-hq.ogg
# 24   files/222179_2385996-hq.ogg
# 25   files/222180_2385996-hq.ogg
# 26   files/222181_2385996-hq.ogg
# 27   files/222182_2385996-hq.ogg
# 28   files/222183_2385996-hq.ogg
# 29   files/222191_2385996-hq.ogg
# ..                           ...
# 120  files/222358_2385996-hq.ogg
# 121  files/222359_2385996-hq.ogg
# 122  files/222360_2385996-hq.ogg
# 123  files/222361_2385996-hq.ogg
# 124  files/222146_2385996-hq.ogg
# 125  files/222170_2385996-hq.ogg
# 126  files/205973_2385996-hq.ogg
# 127  files/206023_2385996-hq.ogg
# 128  files/222233_2385996-hq.ogg
# 129  files/222132_2385996-hq.ogg
# 130  files/222133_2385996-hq.ogg
# 131  files/222135_2385996-hq.ogg
# 132  files/222136_2385996-hq.ogg
# 133  files/222137_2385996-hq.ogg
# 134  files/222138_2385996-hq.ogg
# 135  files/222139_2385996-hq.ogg
# 136  files/222140_2385996-hq.ogg
# 137  files/222141_2385996-hq.ogg
# 138  files/222142_2385996-hq.ogg
# 139  files/222143_2385996-hq.ogg
# 140  files/222144_2385996-hq.ogg
# 141  files/222145_2385996-hq.ogg
# 142  files/222148_2385996-hq.ogg
# 143  files/222150_2385996-hq.ogg
# 144  files/222151_2385996-hq.ogg
# 145  files/222154_2385996-hq.ogg
# 146  files/222155_2385996-hq.ogg
# 147  files/222156_2385996-hq.ogg
# 148  files/222157_2385996-hq.ogg
# 149  files/222160_2385996-hq.ogg
#
#                                                   tags username
# 0    [chinese-traditional, gong, chinese, idiophone...   ajaysm
# 1    [chinese-traditional, gong, chinese, idiophone...   ajaysm
# 2    [chinese-traditional, cymbals, chinese, idioph...   ajaysm
# 3    [chinese-traditional, gong, chinese, idiophone...   ajaysm
# 4    [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 5    [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 6    [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 7    [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 8    [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 9    [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 10   [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 11   [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 12   [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 13   [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 14   [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 15   [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 16   [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 17   [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 18   [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 19   [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 20   [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 21   [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 22   [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 23   [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 24   [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 25   [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 26   [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 27   [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 28   [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 29   [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# ..                                                 ...      ...
# 120  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 121  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 122  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 123  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 124  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 125  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 126  [chinese-traditional, chinese, beijing-opera, ...   ajaysm
# 127  [chinese-traditional, gong, chinese, idiophone...   ajaysm
# 128  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 129  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 130  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 131  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 132  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 133  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 134  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 135  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 136  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 137  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 138  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 139  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 140  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 141  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 142  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 143  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 144  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 145  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 146  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 147  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 148  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
# 149  [icassp2014-dataset, peking-opera, beijing-ope...   ajaysm
#
# [150 rows x 6 columns]
